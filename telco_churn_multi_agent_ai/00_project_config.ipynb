# %%
# Unity Catalog
CATALOG = "dbw_agentic_ai_dev"
SCHEMA = "telco_ai"

# Tables
BRONZE_TABLE = f"{CATALOG}.{SCHEMA}.bronze_telco"
SILVER_TABLE = f"{CATALOG}.{SCHEMA}.silver_telco"
GOLD_TABLE = f"{CATALOG}.{SCHEMA}.gold_telco"

NOTES_TABLE = f"{CATALOG}.{SCHEMA}.customer_notes"
EMBEDDINGS_TABLE = f"{CATALOG}.{SCHEMA}.customer_note_embeddings"

MODEL_RESULTS_TABLE = f"{CATALOG}.{SCHEMA}.model_training_results"
BEST_MODEL_TABLE = f"{CATALOG}.{SCHEMA}.best_model_info"

# Registered model and serving endpoint
REGISTERED_MODEL_NAME = f"{CATALOG}.{SCHEMA}.telco_churn_model"
MODEL_SERVING_ENDPOINT = "telco-churn-endpoint"

# Foundation models
EMBEDDING_MODEL = "databricks-gte-large-en"
LLM_MODEL = "databricks-meta-llama-3-1-8b-instruct"

# Vector Search
VECTOR_SEARCH_ENDPOINT_NAME = "telco-vector-search-endpoint"
VECTOR_INDEX_NAME = (
    f"{CATALOG}.{SCHEMA}.customer_note_embeddings_index"
)
