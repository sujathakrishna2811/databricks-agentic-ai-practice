# %% [markdown]
# ### Learning Journey

# %% [markdown]
# ###### Phase 1 — Machine Learning Foundations (Completed)
#
# ###### Goal
#
# Learn the fundamentals of Machine Learning before using cloud services.
#
# ###### Projects
#
# - Titanic Survival Prediction
# - Netflix Movies & TV Shows EDA
# - Superstore Sales Analysis
# - IBM Telco Customer Churn
#
# ###### Concepts Learned
#
# - Data Cleaning
# - EDA
# - Feature Engineering
# - Logistic Regression
# - Decision Tree
# - Random Forest
# - Evaluation Metrics
# - Confusion Matrix
# - ROC AUC
# - Feature Importance
#
# ###### Big Learnings
#
# - Good data is more important than a complex model.
# - Feature engineering significantly impacts model performance.
# - Evaluation metrics should match the business problem.

# %% [markdown]
# ###### Phase 2 — Azure Machine Learning (Completed)
#
# ###### Goal
#
# Learn enterprise ML lifecycle.
#
# ###### Projects
#
# - Azure ML Jobs
# - Hyperparameter Sweep
# - Model Registration
# - Managed Online Endpoint
# - GitHub Actions CI/CD
#
# ###### Concepts Learned
#
# - Azure ML Workspace
# - Compute Clusters
# - Jobs
# - Experiments
# - Registered Models
# - Endpoints
# - Deployment
# - CI/CD
#
# ###### Big Learnings
#
# - Training and deployment are independent processes.
# - Registered models simplify version management.
# - Production AI is much more than training a model.

# %% [markdown]
# ###### Phase 3 — Azure AI Engineer Skills (Completed)
#
# ###### Projects
#
# - Azure OpenAI
# - Prompt Engineering
# - Document Q&A
# - TF-IDF RAG
# - Embedding-based RAG
# - Hybrid Search
#
# ###### Concepts Learned
#
# - Prompts
# - Embeddings
# - Vector Search
# - Cosine Similarity
# - RAG
# - OpenAI APIs
#
# ###### Big Learnings
#
# - LLMs don't memorize documents—they retrieve relevant context.
# - Embeddings represent meaning rather than exact words.
# - Retrieval quality determines answer quality.

# %% [markdown]
# ###### Phase 4 — Databricks Lakehouse + MLOps + Agentic AI Foundations
#
# ###### Projects
#
# - Bronze → Silver → Gold
# - Telco Churn End-to-End ML Pipeline
# - MLflow
# - Unity Catalog
# - Model Registry
# - Model Serving
# - Support Ticket NLP Classification
#
# ###### Concepts Learned
#
# ###### Lakehouse
#
# - Unity Catalog
# - Delta Lake
# - Volumes
# - Bronze / Silver / Gold
#
# ###### MLOps
#
# - MLflow Experiments
# - Runs
# - Parameters
# - Metrics
# - Artifacts
# - Model Signature
# - Input Example
# - Model Registry
# - Model Serving
#
# ###### Traditional NLP
#
# - Text Cleaning
# - TF-IDF
# - Pipeline
# - Multiclass Classification
#
# ###### Modern NLP Foundations (Conceptual)
#
# - Embeddings
# - Vector Search
# - Semantic Search
#
# ###### RAG Foundations (Conceptual)
#
# - Retrieval
# - Knowledge Grounding
# - Context Injection
#
# ###### Agentic AI Foundations (Conceptual)
#
# - Agents
# - Tool Calling
# - Planning
# - Reasoning
# - Multi-step Workflows
#
# ###### Big Learnings
#
# - Databricks integrates data engineering, machine learning, and AI into a single unified platform.
# - MLflow artifacts contain everything required to reproduce and deploy a model, including the model, signature, dependencies, and input examples.
# - Traditional NLP using TF-IDF remains valuable because it is fast, interpretable, and an excellent baseline for text classification.
# - Embeddings represent the meaning of text rather than simply counting words, enabling semantic search and retrieval.
# - RAG does not train an LLM with new knowledge; instead, it retrieves relevant information and provides it as context before the LLM generates a response.
# - Better retrieval leads to better AI responses—the quality of the retrieved context is often more important than the size of the language model.
# - Agentic AI extends RAG by allowing an AI agent to reason, plan, and choose the appropriate tools before producing an answer.
# - AI systems differ mainly in how data is represented: structured features for ML, TF-IDF vectors for traditional NLP, embeddings for modern NLP, and multimodal representations for vision and multimodal AI.
# - Every AI application follows the same high-level lifecycle: Data → Representation → AI Model → Evaluation → Deployment/Application.
#
#
# ###### Personal Insight:
#
# I learned that understanding the architecture and purpose behind each component (MLflow, Unity Catalog, TF-IDF, RAG, Agentic AI) is more valuable than simply getting the code to run. Building complete end-to-end projects helped me connect individual technologies into a unified AI engineering workflow.

# %% [markdown]
# ###### Phase 5 - Databricks GenAI & Agentic AI (Current / Next)
#
#
# ###### Projects
#
# - Embedding Generation
# - Vector Search Index
# - Document RAG
# - Agent Framework
# - Multi-Agent Workflow
# - Evaluation
# - Production Agent
#
# ###### Concepts
#
# - Databricks Vector Search
# - Embedding Models
# - LangChain / AI Functions
# - MCP
# - Agents
# - Memory
# - Planning
# - Tool Use
# - Agent Evaluation

# %% [markdown]
# ###### Phase 6 — Next Journey
#
# - Embeddings
# - Vector Search
# - RAG
# - Agentic AI
# - Computer Vision
# - Multimodal AI
# - Responsible AI

# %% [markdown]
# ###### Biggest Lessons
#
# The 10 biggest lessons from this journey
#
# 1. Good data is more important than a complex model.
# 2. Feature engineering often improves performance more than changing algorithms.
# 3. MLflow tracks the complete lifecycle of experiments.
#
# 4. A logged model is different from a registered model.
#
# 5. Unity Catalog governs models just like tables.
#
# 6. Traditional NLP is still valuable for many business problems.
#
# 7. Embeddings capture semantic meaning, not exact words.
#
# 8. RAG improves LLM responses by grounding them with retrieved knowledge.
#
# 9. Agentic AI is about orchestrating tools to accomplish tasks, not just generating text.
#
# 10. Building end-to-end projects teaches far more than learning individual concepts in isolation.

# %% [markdown]
# 2026
#
# ```text
#
# Azure Data Engineer
# ↓
# Started Machine Learning
# ↓
# Built First ML Models
# ↓
# Azure ML
# ↓
# Azure OpenAI
# ↓
# RAG
# ↓
# Databricks Lakehouse
# ↓
# MLflow
# ↓
# Unity Catalog
# ↓
# Model Registry
# ↓
# Traditional NLP
# ↓
# Embeddings
# ↓
# Vector Search
# ↓
# RAG
# ↓
# Agentic AI
# ↓
# Production AI Engineer
#
# ```
