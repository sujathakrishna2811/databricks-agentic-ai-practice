# %% [markdown]
# ### AI Foundations
#
# ###### Purpose
#
# This notebook serves as a personal AI handbook that captures concepts, architectures, comparisons, interview notes, and key learnings throughout the Machine Learning and Generative AI journey.

# %% [markdown]
# ###### How to Use This Notebook
#
# - This notebook is organized as a living AI handbook.
# - Each chapter focuses on one AI domain.
# - The supporting sections (Glossary, Interview Preparation, Architectures, Cheat Sheets, Timeline, and Common Mistakes) are continuously updated as new concepts are learned throughout future projects.

# %% [markdown]
# #### AI Foundations Tree
#
# ```text
#
# AI Foundations - Table of Contents
#
# AI Foundations
# │
# ├── Machine Learning
# │   ├── ML Fundamentals
# │   ├── Supervised Learning
# │   ├── Feature Engineering
# │   ├── Model Training
# │   ├── Evaluation Metrics
# │   ├── Model Selection
# │   └── Model Deployment
# │
# ├── Deep Learning
# |
# ├── Data Preparation for Neural Networks
# │   │
# │   ├── Features and Target
# │   │   ├── X = Input Features
# │   │   └── y = Target
# │   │
# │   ├── Feature Types
# │   │   ├── Continuous Numerical
# │   │   ├── Binary
# │   │   └── Categorical
# │   │
# │   ├── Missing Data
# │   │   └── Imputation
# │   │       └── Median Imputation
# │   │
# │   ├── Numerical Feature Scaling
# │   │   └── StandardScaler
# │   │       ├── Mean
# │   │       ├── Standard Deviation
# │   │       └── Standardized Values
# │   │
# │   ├── Categorical Encoding
# │   │   └── One-Hot Encoding
# │   │
# │   ├── Data Leakage Prevention
# │   │   ├── Fit on Training Data
# │   │   ├── Transform Validation Data
# │   │   └── Transform Test Data
# │   │
# │   ├── Dataset Splitting
# │   │   ├── Training Set
# │   │   ├── Validation Set
# │   │   ├── Test Set
# │   │   └── Stratification
# │   │
# │   ├── Scikit-learn Preprocessing
# │   │   ├── Pipeline
# │   │   ├── ColumnTransformer
# │   │   ├── fit()
# │   │   ├── transform()
# │   │   └── fit_transform()
# │   │
# │   ├── NumPy Arrays
# │   │
# │   ├── PyTorch Tensors
# │   │   ├── torch.Tensor
# │   │   ├── float32
# │   │   ├── Tensor Shape
# │   │   └── unsqueeze()
# │   │
# │   ├── TensorDataset
# │   │   └── Pair Features with Targets
# │   │
# │   └── DataLoader
# │       ├── Batch
# │       ├── Batch Size
# │       ├── Shuffle
# │       └── Training Batches
#
# |── Neural Network Fundamentals
# |   |   ├── Deep Learning
# │   │   ├── Neural Networks
# │   │   ├── Neurons
# │   │   ├── Inputs
# │   │   ├── Weights
# │   │   ├── Bias
# │   │   ├── Weighted Sum
# │   │   ├── Activation Functions
# │   │   ├── Input Layer
# │   │   ├── Hidden Layers
# │   │   └── Output Layer
# │   │
# │   ├── Neural Network Training
# │   │   ├── Forward Propagation
# │   │   ├── Loss Functions
# │   │   ├── Backpropagation
# │   │   ├── Gradients
# │   │   ├── Gradient Descent
# │   │   ├── Optimizers
# │   │   ├── Learning Rate
# │   │   ├── Batch Size
# │   │   └── Epochs
# │   │
# │ Deep Learning
# │
# ├── Neural Network Fundamentals
# │   ├── Deep Learning
# │   ├── Neural Networks
# │   ├── Neurons
# │   ├── Inputs
# │   ├── Weights
# │   ├── Bias
# │   ├── Weighted Sum
# │   ├── Activation Functions
# │   ├── Input Layer
# │   ├── Hidden Layers
# │   └── Output Layer
# │
# ├── Activation Functions
# │   ├── ReLU
# │   ├── Sigmoid
# │   └── Softmax
# │
# ├── Neural Network Training
# │   ├── Forward Propagation
# │   ├── Prediction
# │   ├── Loss Functions
# │   │   └── Binary Cross-Entropy
# │   ├── Backpropagation
# │   ├── Gradients
# │   ├── Chain Rule
# │   ├── Gradient Descent
# │   ├── Optimizers
# │   │   ├── SGD
# │   │   └── Adam
# │   ├── Learning Rate
# │   ├── Batch
# │   ├── Batch Size
# │   ├── Iteration
# │   └── Epoch
# │
# ├── Model Development
# │   ├── Parameters
# │   │   ├── Weights
# │   │   └── Biases
# │   │
# │   └── Hyperparameters
# │       ├── Hidden Layers
# │       ├── Neurons
# │       ├── Learning Rate
# │       ├── Batch Size
# │       ├── Epochs
# │       └── Optimizer
# │
# ├── Data Preparation for Neural Networks
# │   ├── X and y
# │   ├── Numerical Features
# │   ├── Binary Features
# │   ├── Categorical Features
# │   ├── Missing Value Imputation
# │   ├── Standardization
# │   ├── One-Hot Encoding
# │   ├── Train / Validation / Test Split
# │   ├── Stratification
# │   ├── Data Leakage Prevention
# │   ├── Pipeline
# │   ├── ColumnTransformer
# │   ├── NumPy Arrays
# │   ├── PyTorch Tensors
# │   ├── TensorDataset
# │   └── DataLoader
# │
# ├── Model Evaluation
# │   ├── Training Loss
# │   ├── Validation Loss
# │   ├── Accuracy
# │   ├── Precision
# │   ├── Recall
# │   ├── F1 Score
# │   ├── ROC-AUC
# │   ├── Confusion Matrix
# │   ├── Classification Threshold
# │   ├── Overfitting
# │   ├── Underfitting
# │   └── Early Stopping
# │
# ├── Deep Learning Frameworks
# │   ├── PyTorch
# │   │   ├── Tensor
# │   │   ├── TensorDataset
# │   │   ├── DataLoader
# │   │   ├── nn.Module
# │   │   ├── nn.Linear
# │   │   ├── Loss Functions
# │   │   └── Optimizers
# │   │
# │   └── TensorFlow / Keras
# │
# └── Deep Learning Applications
#     ├── Tabular Data
#     ├── Natural Language Processing
#     ├── Computer Vision
#     └── Generative AI
# │
# |── Natural Language Processing
# |   |
# │   ├── Traditional NLP
# │   │   ├── Text Preprocessing
# │   │   ├── TF-IDF
# │   │   ├── Bag of Words
# │   │   └── Text Classification
# │   │
# │   ├── Modern NLP
# │   │   ├── Embeddings
# │   │   ├── Transformers
# │   │   ├── Semantic Search
# │   │   └── Vector Search
# |        |__ Simialrity Search
# │
# ├── Generative AI
# |   |
# │   ├── Large Language Models (LLMs)
# │   │   ├── Foundation Models
# │   │   ├── Context Window
# │   │   ├── Tokens
# │   │   └── Temperature
# │   │
# │   ├── Prompt Engineering
# │   │   ├── Zero-shot
# │   │   ├── Few-shot
# │   │   ├── Chain of Thought
# │   │   └── System Prompts
# │   │
# │   ├── RAG (Retrieval-Augmented Generation)
# │   │   ├── Retrieval
# │   │   ├── Chunking
# │   │   ├── Vector Database
# │   │   ├── Context Injection
# │   │   └── Grounding
# │   │
# │   └── Agentic AI
# │       ├── Agents
# │       ├── Planning
# │       ├── Tool Calling
# │       ├── Memory
# │       ├── Multi-Agent Systems
# │       └── Agent Evaluation
#
# │── Agent Design Patterns
# │     │
# │     ├── Tool Selection
# │     ├── Tool Registry
# │     ├── Tool Execution
# │     ├── Prompt Routing
# │     ├── Retrieval
# │     ├── Reasoning
# │     └── Final Response Generation
# │
# ├── Vision AI
# │   ├── Computer Vision
# │   ├── Image Processing
# │   ├── Object Detection
# │   ├── OCR
# │   └── Multimodal AI
# │
# ├── Responsible AI
# │   ├── Responsible AI Principles
# │   ├── AI Governance
# │   ├── AI Security
# │   └── AI Evaluation
# │
# ├── Production AI
# │   ├── Fine-tuning
# │   ├── AI Observability
# │   ├── Monitoring
# │   ├── Logging
# │   ├── Cost Optimization
# │   ├── Latency
# │   └── A/B Testing
# │
# ├── Real Projects
# │   ├── Titanic Survival Prediction
# │   ├── Netflix Movies & TV Shows EDA
# │   ├── Superstore Sales Analysis
# │   ├── IBM Telco Churn Prediction
# │   ├── Azure ML MLOps
# │   ├── Azure OpenAI RAG
# │   ├── Databricks Telco Churn Pipeline
# │   ├── Support Ticket NLP Classification
# │   └── Future Agentic AI Projects
# │
# └── Reference
#     ├── Interview Preparation
#     ├── AI Glossary
#     ├── Architectures
#     ├── Cheat Sheets
#     ├── Comparison Tables
#     ├── Timeline
#     └── Common Mistakes & Lessons Learned
# ```

# %% [markdown]
# ###### Last Updated : June 2026

# %% [markdown]
# ### Chapter 1 - ML (Machine Learning)

# %% [markdown]
# ###### Structured Machine Learning Pipeline
#
# ``` text
#
# Raw Data
#     ↓
# Data Cleaning
#     ↓
# Exploratory Data Analysis (EDA)
#     ↓
# Feature Engineering
#     ↓
# Train/Test Split
#     ↓
# Model Training
#     ↓
# Model Evaluation
#     ↓
# Model Selection
#     ↓
# Model Registry
#     ↓
# Model Serving
# ```

# %% [markdown]
# ###### Data Preparation
# - Missing value treatment
# - Duplicate removal
# - Outlier handling
# - Encoding categorical variables
# - Scaling numerical variables

# %% [markdown]
# ###### Feature Engineering
# - Feature selection
# - Feature creation
# - Feature transformation

# %% [markdown]
# ###### Model Training
# - Logistic Regression
# - Decision Tree
# - Random Forest
# - XGBoost

# %% [markdown]
# ###### Model Evaluation
# - Accuracy
# - Precision
# - Recall
# - F1-score
# - ROC-AUC (binary)
# - Macro Precision
# - Macro Recall
# - Macro F1 (multiclass)
# - Confusion Matrix
# - Classification Report

# %% [markdown]
# ###### MLOps
#
# - MLflow Experiment
# - MLflow Run
# - Parameters
# - Metrics
# - Artifacts
# - Model Signature
# - Input Example
# - Model Registry
# - Model Serving

# %% [markdown]
# ### Chapter 2 - Traditional NLP (Natural Language Processing)

# %% [markdown]
# ###### Traditional NLP Building Blocks
#
# 1. Text Preprocessing
#
#    - Tokenization ->  Split into words. Sentence -> Words
#    - Stop Words Removal -> Stop words are common words(the, a, is, of, and a, an, to)These usually add little meaning.
#    - Stemming -> Reduce words to a root form. Ex: connecting, connected, connection --> connect
#    - Lemmatization -> Similar to stemming but smarter. Ex: running, runs, ran to run. This preserves actual dictionary meaning.
#
# 2. Text Representation
#
#    - Vocabulary ->  Collect every unique word.
#    - Bag of Words -> count how many times each vocabulary word appears.
#    - Term Frequency (TF)
#    - Inverse Document Frequency (IDF)
#    - TF-IDF
#
# 3. Feature Engineering
#
#    - TF-IDF converts text into numerical features for Machine Learning.
#
# 4. Key Idea
#
#    TF-IDF asks two questions:
#    -  How important is this word in this document?
#    -  Does this word appear in every document?
#
#
# ```text
#
#    Raw Text
#      ↓
# Text Preprocessing
#      ↓
# Text Representation
#      ↓
# Feature Engineering
#     ↓
# Machine Learning Model
# ```

# %% [markdown]
# ###### Traditional NLP Pipeline
#
# ```text
#
# Raw Text
#  ↓
# Text Cleaning
#  ↓
# Tokenization
#  ↓
# Vocabulary
#  ↓
# Bag of Words
#  ↓
# TF-IDF
#  ↓
# Feature Matrix
#  ↓
# Machine Learning Model
#  ↓
# Classification
#
# TF-IDF is feature engineering for text.
# ```

# %% [markdown]
# ###### Before embeddings existed:
#
# ```text
#
# Text
#  ↓
# TF-IDF
#  ↓
# Machine Learning
#
# ```
# This worked surprisingly well for:
#
# - Spam detection
# - Sentiment analysis
# - Ticket classification
# - Email classification
# - News categorization
#
# Even today, TF-IDF is still used because it's:
#
# - Fast
# - Interpretable
# - Doesn't require GPUs or LLMs
# - Great baseline for text classification

# %% [markdown]
# ### Chapter 3 - Modern NLP

# %% [markdown]
# %md
# Modern NLP (Embeddings)
#
# ```text
#
# Text
#  ↓
# Embeddings
#  ↓
# Vector
#  ↓
# LLM / Vector Search
#  ↓
# Answer
# ```

# %% [markdown]
# - What is an embedding?
#    - An embedding is a dense numerical vector that represents the semantic meaning of text.
#
# - Why do we need embeddings?
#    - Embedding models convert text into vectors because Vector Search compares vectors, not raw text.
#
# - Why are vectors better than TF-IDF?
#   - TF-IDF matches important words, while embeddings capture the meaning of the entire sentence, allowing semantic search.
#
# - Why do similar sentences have similar vectors?
#   - Embedding models place semantically similar sentences close together in vector space.
#
# - What is vector dimension?
#   - Vector dimension is the number of numerical values contained in an embedding vector.
#
# - What is cosine similarity?
#   - Cosine similarity measures how similar two vectors are by comparing the angle between them rather than their length.
#
# - Why do we store embeddings?
#   - Embeddings are stored in Delta tables so they can later be indexed by Vector Search and used for semantic retrieval, RAG, and Agentic AI applications.

# %% [markdown]
# ###### The Evolution of NLP
#
# ```text
#
# Sentence
#     ↓
# Tokenization
#     ↓
# Vocabulary
#     ↓
# Bag of Words
#     ↓
# Counts words
#     ↓
# TF-IDF
#     ↓
# Weights important words
#     ↓
# Embeddings
#     ↓
# Understand meaning
#     ↓
# Vector Search
#     ↓
# Retrieve semantically similar text
#     ↓
# RAG
#     ↓
# LLM generates answer
#
# ```
#
# Notice how every stage solved a limitation of the previous one.

# %% [markdown]
# So Chapter 3 will include:
#
# - What are embeddings?
# - Why embeddings replaced TF-IDF
# - Embedding dimensions
# - Cosine similarity
# - Vector search
# - Vector databases
# - Semantic search
# - Chunking
# - Embedding models
#
# That keeps everything related together.

# %% [markdown]
# ### Chapter 4 - Large Language Models (LLMs)

# %% [markdown]
# This chapter would include:
#
# - Transformers (high level)
# - Attention
# - Tokens
# - Context Window
# - Temperature
# - Top-k / Top-p
# - Hallucinations
# - Fine-tuning vs Prompting
# - OpenAI
# - Llama
# - Mistral
# - Phi
# - Claude
# - Gemini

# %% [markdown]
# ### Chapter 5 - Prompt Engineering

# %% [markdown]
# This would include:
#
# - System Prompt
# - User Prompt
# - Assistant Prompt
# - Zero-shot
# - One-shot
# - Few-shot
# - Chain of Thought
# - Structured Output
# - JSON Mode
# - Tool Calling
# - Function Calling
# - Prompt Templates

# %% [markdown]
# ### Chapter 6 - RAG

# %% [markdown]
# ``` text
#
# Raw Documents
# ↓
# Chunking
# ↓
# Embeddings
# ↓
# Vector Search
# ↓
# Retriever
# ↓
# Prompt
# ↓
# LLM
# ↓
# Answer
#
# ```

# %% [markdown]
# Including:
#
# - Chunking
# - Chunk overlap
# - Retrieval
# - Top-K
# - Hybrid Search
# - Metadata Filtering
# - Reranking
# - Grounding

# %% [markdown]
# ### Chapter 7 - Agentic AI

# %% [markdown]
# Including:
#
# - What is an Agent?
# - Agent vs Workflow
# - Planning
# - Reasoning
# - Memory
# - Tools
# - MCP
# - Multi-Agent Systems
# - Evaluation
# - Agent Frameworks

# %% [markdown]
# #### Deep Learning → Neural Networks

# %% [markdown]
# ### Chapter 8 - Computer Vision

# %% [markdown]
# Including:
#
# - Images
# - CNNs
# - Vision Transformers
# - Object Detection
# - OCR
# - Image Classification
# - Segmentation

# %% [markdown]
# ### Chapter 9 - Multimodal AI

# %% [markdown]
# Including:
#
# - Text + Image
# - Audio
# - Video
# - Vision-Language Models
# - Multimodal RAG

# %% [markdown]
# ##### Chapter 10 - Responsible AI

# %% [markdown]
# Including:
#
# - Bias
# - Fairness
# - Explainability
# - Privacy
# - Hallucinations
# - AI Governance
# - Safety
# - Monitoring

# %% [markdown]
# ###  Interview Preparation

# %% [markdown]
# ##### Machine Learning
#
# Q. What is Machine Learning?
#
# Q. Difference between AI and Machine Learning?
#
# Q. What is Feature Engineering?
#
# Q. Why split data into Train and Test?
#
# Q. Difference between Classification and Regression?
#
# Q. What is Overfitting?
#
# Q. Why use Precision instead of Accuracy?
#
# Q. Why use Recall?
#
# Q. Why use F1 Score?
#
# Q. Why F1 Macro for multiclass classification?
#
# Q. When should ROC-AUC be used?

# %% [markdown]
# ##### NLP
#
# Q. Why remove stop words?
#
# Q. Difference between Stemming and Lemmatization?
#
# Q. What is TF-IDF?
#
# Q. Why use TF-IDF instead of Bag of Words?
#
# Q. Why can't ML models understand raw text?

# %% [markdown]
# ##### MLflow
#
# Q. Difference between Experiment and Run?
#
# Q. What is artifact_path?
#
# Q. What is model_uri?
#
# Q. Difference between model.pkl and MLmodel?
#
# Q. Why do we log metrics?
#
# Q. Why create a Signature?
#
# Q. Why create Input Example?
#
# Q. What are MLflow Artifacts?

# %% [markdown]
# ##### Databricks
#
# Q. Why Bronze, Silver and Gold?
#
# Q. Difference between Catalog and Schema?
#
# Q. What is Unity Catalog?
#
# Q. Why register a model?
#
# Q. Why Model Serving?

# %% [markdown]
# ##### GenAI
#
# Q. What are Embeddings?
#
# Q. Why Embeddings instead of TF-IDF?
#
# Q. What is Vector Search?
#
#   - A search technique that retrieves documents based on semantic similarity using embeddings instead of keyword matching.
#
# Q. Why do we need embeddings before Vector Search?
#
#   - Vector Search operates on numerical vectors, not raw text.
#
# Q. Why must the same embedding model be used?
#
#   - Documents and user questions must exist in the same vector space for cosine similarity to be meaningful.
#
# Q. What is Delta Sync Index?
#
#   - A Databricks-managed vector index that automatically synchronizes embedding vectors from a Delta table.
#
# Q. Why enable Change Data Feed?
#
#   - It allows the Delta Sync Index to detect inserts, updates, and deletes so the vector index stays synchronized.
#
# Q. What does the Vector Search Endpoint do?
#
#  - It exposes the vector index through an endpoint so applications can perform similarity search.
#
# Q. What is Semantic Search?
#  - Semantic Search retrieves documents with similar meaning even when the words differ.
#
# Q. What is cosine similarity?
#  - Vector Search returns the nearest vectors using cosine similarity.
#
# Q. Importance of using the same embedding model for indexing and querying?
#
#
# - TF-IDF asks: "Which words are important?"
# - Embeddings ask: "What does this sentence mean?"

# %% [markdown]
# ##### RAG
#
# Q. What problem does RAG solve?
#
# Q. Why not just use an LLM?
#
# Q. What is a Retriever?
#
# Q. What is Context Injection?
#
# Q. Why chunk documents?

# %% [markdown]
# ##### Agentic AI
#
# Q. What is an AI Agent?
#
# Q. Difference between RAG and Agentic AI?
#
# Q. What is Tool Calling?
#
# Q. Why Planning?
#
# Q. What makes an AI system Agentic?

# %% [markdown]
# ### Concept Connections

# %% [markdown]
# How does TF-IDF relate to Embeddings?
#
# ``` text
#
# TF-IDF
#     ↓
# Traditional NLP
#
# Embeddings
#     ↓
# Modern NLP
#
# Both
#     ↓
# Convert text into numbers
#
# ```

# %% [markdown]
# ``` text
# ML
#     ↓
# Prediction
#
# NLP
#     ↓
# Text Prediction
#
# RAG
#     ↓
# Knowledge + Prediction
#
# Agentic AI
#     ↓
# Reasoning + Tools + Prediction
# ```

# %% [markdown]
# ``` text
# Raw Data
#     ↓
# Representation
#     ↓
# Model
#     ↓
# Evaluation
#     ↓
# Deployment
# ```

# %% [markdown]
# Above ML, NLP, RAG, Embeddings - those 4 are not unrelated topics but they are different ways of solving the same problem.
#
#
# ```text
#
# Data
#       ↓
# Preparation
#       ↓
# Representation
#       ↓
# AI Model
#       ↓
# Evaluation
#       ↓
# Deployment/Application
#
# ```

# %% [markdown]
# ```text
# 17 Training
# ↓
# Built multiple NLP models
#
# 18 Evaluation
# ↓
# Selected the best model
#
# 19 MLflow
# ↓
# Tracked experiments
#
# 20 Registry
# ↓
# Versioned the model
#
# 21 Serving
# ↓
# Deployed the model
#
# 22 Embeddings
# ↓
# Represented text as vectors
#
# 23 Vector Search
# ↓
# Enabled semantic retrieval
#
# 24 RAG
# ↓
# Generate grounded answers with an LLM
#
# 25 Agentic AI
# ↓
# Reason, use tools, and automate tasks
# ```

# %% [markdown]
# Definition
#
# A managed Vector Search index that automatically or manually synchronizes embedding vectors from a Delta table.
#
# Why?
#
# Keeps the vector index consistent with the latest data stored in Delta.
#
# Pipeline Types
#
# TRIGGERED
# Manual synchronization using index.sync()
#
# CONTINUOUS
# Automatically synchronizes changes.

# %% [markdown]
# Below is how each domain changes only the representation:
#
# - Machine Learning → engineered numerical features
# - Traditional NLP → TF-IDF vectors
# - Modern NLP → embeddings
# - Computer Vision → image tensors
# - RAG → embeddings + retrieved context
# - Agentic AI → tools + reasoning + memory

# %% [markdown]
# ###### AI Core Principles
#
# - AI starts with data.
# - Every AI system converts raw data into a representation.
# - Better representations lead to better predictions.
# - Traditional ML uses engineered numeric features.
# - Traditional NLP uses TF-IDF features.
# - Modern NLP uses embeddings.
# - RAG retrieves knowledge before answering.
# - Agentic AI decides which tools to use before answering.

# %% [markdown]
# ### Comparison Tables

# %% [markdown]
# | TF-IDF                 | Embeddings          |
# | ---------------------- | ------------------- |
# | Sparse vector          | Dense vector        |
# | Mostly zeros           | Almost no zeros     |
# | Represents words       | Represents meaning  |
# | Exact keyword matching | Semantic similarity |
# | Traditional NLP        | Modern NLP          |

# %% [markdown]
# | Technology | Simple analogy            | Main purpose                           |
# | ---------- | ------------------------- | -------------------------------------- |
# | LangChain  | Vehicles and equipment    | Connect LLMs, prompts, data, and tools |
# | LangGraph  | Roads and traffic routes  | Control workflow order and branching   |
# | LangSmith  | Traffic monitoring system | Trace, debug, test, and evaluate       |

# %% [markdown]
# | Item                   | Purpose                                                                                 |
# | ---------------------- | --------------------------------------------------------------------------------------- |
# | Prediction Probability | The model's confidence for a specific prediction (if the model provides it)             |
# | Predicted Class        | The final category or label (e.g., Technical, Billing, Churn)                           |
# | ROC AUC                | An evaluation metric calculated using many prediction probabilities and the true labels |

# %% [markdown]
# | Component                | Responsibility                                                                    |
# | ------------------------ | --------------------------------------------------------------------------------- |
# | **Coordinator Agent**    | Orchestrates **which agents** should run and in what order.                       |
# | **Specialist Agent**     | Orchestrates **how its tool is used** and validates/stores the results.           |
# | **Tool**                 | Performs the actual business logic (SQL, prediction, vector search, LLM, etc.).   |
# | **Shared State**         | Carries information from one agent to another.                                    |
# | **Final Response Agent** | Orchestrates the creation of the final user-facing answer from all agent results. |

# %% [markdown]
# - Agents coordinate work, Tools perform work, and Shared State enables communication between agents.

# %% [markdown]
# | Agent                | Validates                                                 |
# | -------------------- | --------------------------------------------------------- |
# | SQL Agent            | SQL results                                               |
# | Prediction Agent     | Prediction + confidence                                   |
# | Vector Search Agent  | Search results list + each individual result              |
# | Retention Agent      | Recommended action + reason                               |
# | Final Response Agent | Final response structure (if using a structured response) |

# %% [markdown]
# ``` text
# Coordinator Agent
#         │
#         ▼
# Decides WHAT should happen
#
# ```
#
# ``` text
#
#
#
# Specialist Agent
#         │
#         ▼
# Decides HOW to use its tool
#
# ```
#
# ``` text
#
#
#
#
# Tool
#         │
#         ▼
# Actually performs the work
#
# ```
#
# ``` text
#
#
#
#
# Shared State
#         │
#         ▼
# Allows agents to communicate
#
# ```
#
# ``` text
#
#
#
#
# Final Response Agent
#         │
#         ▼
# Combines everything into one grounded answer
#
# ```

# %% [markdown]
# ``` text
#
# ML Model
#      │
#      ▼
# Prediction Probability (if the model provides it)
#      │
#      ├── Used to make the prediction
#      └── Can be used to calculate ROC AUC
#
# ```

# %% [markdown]
# ML Model Confidence
# - Comes from the model (e.g., predict_proba() in Logistic Regression or Random Forest).
# - Example: "Technical (0.93 probability)."
#
# LLM Confidence
# - Large language models generally do not provide a calibrated confidence score.
# - If you see something labeled as "confidence" in an LLM application, it's often an application-defined score or heuristic, not a true probability.

# %% [markdown]
# ### Architectures

# %% [markdown]
# **Churn Prediction**
#
# ```text
#
# Raw Data
#       ↓
# Bronze
#       ↓
# Silver
#       ↓
# Gold
#       ↓
# Feature Engineering
#       ↓
# Machine Learning
#       ↓
# Evaluation
#       ↓
# Serving
#
# ```

# %% [markdown]
# **Support Ticket NLP with out embeddings**
#
# ```text
#
# Raw Tickets
#       ↓
# Bronze
#       ↓
# Silver
#       ↓
# Gold
#       ↓
# TF-IDF
#       ↓
# Machine Learning
#       ↓
# Evaluation
#
# ```

# %% [markdown]
# **Embedding-Based Semantic Search Architecture**
#
# ```text
#                 OFFLINE INDEXING
#
# Support Documents
#         │
#         ▼
# Embedding Model (GTE)
#         │
#         ▼
# Document Embeddings
#         │
#         ▼
# Vector Search Index
# ──────────────────────────────────────────
#
#                  ONLINE QUERY
#
# User Question
#         │
#         ▼
# Same Embedding Model (GTE)
#         │
#         ▼
# Question Embedding
#         │
#         ▼
# Cosine Similarity Search
#         │
#         ▼
# Top-k Relevant Documents
#         │
#         ▼
# LLM
#         │
#         ▼
# Final Answer
# ```

# %% [markdown]
# **Transformer**
# -The Transformer is the neural network architecture.The Embedding is one of its outputs.
#
# ```text
# Text
# ↓
# Transformer
#    ├── Understands context
#    ├── Learns relationships between words
#    ├── Produces contextual embeddings
#    └── Can generate text
# ↓
# Embedding
# ↓
# Vector Search
# ↓
# RAG
# ↓
# Agentic AI
# ```

# %% [markdown]
# **RAG**
#
# ```text
#
# Raw Documents
#       ↓
# Bronze
#       ↓
# Silver
#       ↓
# Gold
#       ↓
# Embeddings
#       ↓
# Vector Search
#       ↓
# LLM
#
# ```

# %% [markdown]
# **Agentic AI**
#
# ```text
#
# Question
#       ↓
# Agent
#       ↓
# Tool Selection
#       ↓
# SQL
# Prediction
# Vector Search
# API
#       ↓
# LLM
#
# ```

# %% [markdown]
# ##### Notebook structure
#
#
# ```text
#
# Purpose
# ↓
#
# Input
# ↓
#
# Output
# ↓
#
# Architecture
# ↓
#
# Sections
# ↓
#
# Code
# ↓
#
# Notebook Summary
# ↓
#
# Key Learnings
# ↓
#
# Next Notebook
# ```

# %% [markdown]
# #### Cheat Sheets

# %% [markdown]
# ##### ML
#
# ```text
#
# Train/Test Split
# ↓
#
# Fit on Train
# ↓
#
# Predict on Test
# ↓
#
# Evaluate
#
# ```

# %% [markdown]
# ##### TF-IDF
#
# ```text
# Raw Text
# ↓
#
# Cleaning
# ↓
#
# Tokenization
# ↓
#
# Vocabulary
# ↓
#
# TF-IDDF
# ↓
#
# Feature Matrix
# ```

# %% [markdown]
# ##### MLflow
#
# ```text
#
# Run
# ↓
#
# Parameters
#
# Metrics
#
# Artifacts
#
# Signature
#
# Input Example
#
# ```

# %% [markdown]
# ###### Model Lifecycle
#
# ```text
#
# Training
#
# ↓
#
# Evaluation
#
# ↓
#
# MLflow
#
# ↓
#
# Registry
#
# ↓
#
# Serving
#
# ↓
#
# Prediction
# ```

# %% [markdown]
# ###### RAG
#
#
# ```text
#
# Question
#
# ↓
#
# Embedding
#
# ↓
#
# Vector Search
#
# ↓
#
# Relevant Chunks
#
# ↓
#
# Prompt
#
# ↓
#
# LLM
#
# ↓
#
# Answer
#
# ```

# %% [markdown]
# ### AI Glossary

# %% [markdown]
# %md
#
# ##### Machine Learning
#
# - Artificial Intelligence (AI) = 	A field of computer science that enables machines to perform tasks requiring human intelligence.
#
# - Machine Learning (ML) = A subset of AI where models learn patterns from data instead of being explicitly programmed.
#
# - Model = A trained algorithm that makes predictions or decisions from data.
#
# - Feature = 	An input variable used by a machine learning model.
#
# - Label / Target	= The value the model is trained to predict.
#
# - Training Data = Data used to teach a machine learning model.
#
# - Test Data = Data used to evaluate how well a trained model performs.
#
# - Feature Engineering	 = Creating or transforming features to improve model performance.
#
# - Classification	= Predicting discrete categories such as Spam or Not Spam.
#
# - Regression = Predicting continuous numerical values.
#
# - Accuracy = 	Percentage of predictions that are correct.
#
# - Precision = Of predicted positives, how many were actually positive.
#
# - Recall	=  Of actual positives, how many were correctly identified.
#
# - F1 Score = 	Harmonic mean of Precision and Recall.
#
# - F1 Macro = 	Average F1 score across all classes, treating each class equally.
#
# - Confusion Matrix = 	A table showing correct and incorrect predictions by class.
#
# - ROC-AUC	= Measures how well a binary classifier separates classes.

# %% [markdown]
# ##### Traditional NLP
#
# - NLP = Enables computers to understand and process human language.
#
# - Tokenization = Splitting text into smaller units such as words.
#
# - Stop Words =	Common words removed because they add little meaning.
#
# - Stemming	= Reduces words to their root form by removing suffixes.
#
# - Lemmatization	= Converts words to their dictionary root while preserving meaning.
#
# - Vocabulary = Collection of all unique words in the dataset.
#
# - Bag of Words = Represents text using word occurrence counts.
#
# - TF  = Measures how often a word appears in one document.
#
# - ID F = Measures how unique a word is across all documents.
#
# - TF-IDF  = Converts text into weighted numerical features for machine learning.
#
# - PyFunc Wrapper = A custom MLflow model wrapper that controls how input data is processed before calling the underlying model.

# %% [markdown]
# ##### Databricks
#
# - Databricks = Unified platform for data engineering, analytics, and AI.
#
# - Unity Catalog = Centralized governance for data, models, and AI assets.
#
# - Catalog = Top-level container for schemas and tables.
#
# - Schema = Logical grouping of related database objects.
#
# - Delta Table = Reliable table format supporting ACID transactions and versioning.
#
# - Bronze Layer = Stores raw ingested data.
#
# - Silver Layer = Stores cleaned and transformed data.
#
# - Gold Layer = Stores business-ready curated data.
#
# - Volume = Managed storage for files in Unity Catalog.
#
# - Model Registry= Stores versioned machine learning models.
#
# - Model Serving = Deploys models as REST API endpoints.
#
# - Databricks Secret Scope = A secure, encrypted container used to store sensitive values such as API keys, passwords, PAT tokens, and connection strings. Secrets are retrieved in notebooks using dbutils.secrets.get() without exposing their values in code or notebook output.

# %% [markdown]
# ##### Modern NLP / GenAI
#
# - Embedding = Numerical vector representing the semantic meaning of text.
#
# - Vector = Ordered list of numbers representing data mathematically.
#
# - Semantic Search	= Finds information based on meaning instead of exact words.
#
# - Vector Search = Retrieves similar embeddings using vector distance.
#
# - LLM	= Large Language Model trained on massive text datasets.
#
# - Prompt = Instructions given to an LLM.
#
# - Dense Vector: A numerical vector in which almost every dimension contains meaningful information, allowing semantic relationships between texts to be captured.
#
# - Semantic Search: Retrieves documents based on meaning rather than exact keyword matches.
#
# - Similarity Search: Finds the vectors most similar to the query vector using a similarity metric such as cosine similarity.
# Semantic Search and Similarity Search are related, but not identical.
#
# ``` text
# Semantic Search
#       ↓ uses
# Similarity Search
#       ↓uses
# Cosine Similarity
#       ↓
# Nearest Vectors
# ```
# - Cosine Similarity: Measures how similar two embedding vectors are by comparing the angle between them. A smaller angle means the text has more similar meaning.
#
# - Same Embedding Model: Documents and user queries must use the same embedding model so their vectors exist in the same vector space, making similarity comparisons meaningful.
#
# - Delta Sync Index = Automatically synchronizes vectors from a Delta table into a Vector Search Index.
#
# - Direct Access Index = A Vector Search Index where vectors are inserted and managed directly by the application.
#
# - Transformer = A deep learning architecture that understands relationships between words in context and produces contextual representations used for embeddings, language understanding, and text generation.
#
# - similarity_search() : Retrieves the most relevant documents by comparing the query embedding with stored document embeddings using cosine similarity.
#
# - ChatMessage : Represents a conversation message sent to an LLM, including the speaker's role (system, user, or assistant) and the message content.
#
# - Prompt: The text instruction sent to an LLM that contains the task, context, and user question.
#
# - Messages: The structured conversation format (system, user, assistant) used by modern LLM APIs to provide instructions, conversation history, and user input.
#
# - System message : permanent instructions for the assistant.
#
# - User message : the current question and retrieved context.

# %% [markdown]
# ##### RAG
#
# - RAG	= Retrieves relevant knowledge before generating an answer.
#
# - Retriever = Finds relevant documents for a query.
#
# - Context	= Retrieved information passed to the LLM.
#
# - Chunk = Small section of a document used for retrieval.
#
# - Knowledge Base= Collection of documents used for retrieval.

# %% [markdown]
# ##### Agentic AI
#
# - Agent = AI system that plans, reasons, and performs tasks.
#
# - Agentic AI	= AI that autonomously plans, selects tools, and executes multi-step workflows. An Agentic AI system is an application that decides which capability (tool) should be used for a user's request, executes that tool, and then combines the results into a final response.
#
# - Tool = External capability an agent can invoke, such as SQL or an API.
#
# - Planning = Breaking a task into multiple steps before execution.
#
# - Reasoning = Deciding what action to take next.
#
# - Workflow = Sequence of actions executed to complete a task.
#
# - Agent Schema = standardized structure every agent must use when writing its results.
#
# - Shared State = shared workspace where all agents store and read information.
#
# - LangChain - LangChain is a Python and JavaScript framework for building applications that use LLMs. LangChain helps an LLM work with prompts, data, and tools.LangChain is useful for:
#
#     -  RAG applications
#     -  Tool-calling agents
#     -  Document question answering
#     -  Chatbots
#     -  Structured LLM responses
#     -  Connecting models to external systems
#
# - LangGraph is used to control a multi-step or multi-agent workflow. LangGraph manages the order in which agents or workflow steps run.LangGraph is designed specifically for stateful, long-running agent workflows and supports features such as persistence, streaming, durable execution, and human approval steps.
# It represents the workflow as a graph:
#     - Nodes = steps or agents
#     - Edges = paths between the steps
#     - State = shared information
#
# LangGraph is especially useful when a workflow needs:
#
#     - Multiple agents
#     - Shared state
#     - Conditional routing
#     - Retry loops
#     - Agent dependencies
#     - Human approval
#     - Pause and resume
#     - Long-running workflows
#
# - LangSmith helps you inspect and evaluate what happened inside an LLM or agent workflow.
#
# - Pydantic models     → Validate agent inputs and outputs.Pydantic acts like a quality gate before anything is written into the shared state.
#
# - TypedDict     → Describe the complete shared workflow state
#
# - Orchestrate means: Manage the workflow by deciding who performs each task, in what order, and how their outputs are combined.

# %% [markdown]
# #### Deep Learning - Neural Networks
#
# ##### Deep Learning
#
# A branch of machine learning that uses neural networks with multiple layers to learn patterns from data.
#
# ``` text
#
# Artificial Intelligence
#         ↓
# Machine Learning
#         ↓
# Deep Learning
#         ↓
# Neural Networks
#
# ```
#
# ##### Neural Network
#
# A machine-learning model composed of interconnected layers of neurons that learn relationships between inputs and outputs.
#
# Example:
#
# ``` text
#
# 45 inputs
#  ↓
# 32 neurons
#  ↓
# 16 neurons
#  ↓
# 1 output
#
# ```
#
# ##### Neuron
#
# A computational unit that receives inputs, combines them using weights and a bias, and produces an output.
#
# z=∑wx+b
#
# where:
#
# - x = input features
# - w = weights
# - b = bias
# - z = weighted sum / linear output
#
# ##### Layer
#
# A collection of neurons operating at the same stage of a neural network.
#
# Common types:
#
# - Input Layer
# - Hidden Layer
# - Output Layer
#
# ##### Input Layer
#
# Represents the features entering the neural network.
#
# Test model: 45 processed features
#
# ##### Hidden Layer
#
# A layer between the input and output that learns intermediate representations and patterns.
#
# Test model has:
#
# - Hidden Layer 1 → 32 neurons
# - Hidden Layer 2 → 16 neurons
#
# ##### Output Layer
#
# The final neural-network layer that produces the model's raw output.
#
# Our binary-classification model uses: 1 output neuron
#
# Why One Output Neuron?
#
# Telco churn is binary:
#
# 0 = No Churn
# 1 = Churn
#
# Therefore the network only needs one output value
#
#
# ##### Weight
#
# A trainable parameter controlling how strongly an incoming value influences a neuron.
#
# Weights are learned during training.
#
# ##### Bias
#
# A trainable parameter added to a neuron's weighted sum.
#
# z=wx+b
#
# The bias allows the neuron to shift its response rather than depending only on weighted inputs.
#
# ##### Parameter
#
# A value learned by the neural network during training.
#
# Examples:
#
# Weights
# Biases
#
# Test network contains: 2,017 trainable parameters
#
#
# ##### Hyperparameter
#
# A setting chosen before/during model development rather than learned directly from the training examples.
#
# Examples:
#
# - Number of hidden layers
# - Number of neurons
# - Learning rate
# - Batch size
# - Number of epochs
# - Optimizer choice
#
# In Test architecture:
#
# 32 neurons → hyperparameter
# 16 neurons → hyperparameter
#
# ##### Fully Connected Layer
#
# A layer in which every neuron receives every output from the previous layer.
#
# nn.Linear implements a fully connected linear transformation.
#
# nn.Linear
#
# PyTorch component that calculates:
#
# y=xW
# T
# +b
#
# Example:
#
# nn.Linear(45, 32)
#
# means:
#
# 45 inputs
# ↓
# 32 outputs
#
# ##### Activation Function
#
# A function applied to a neuron's linear output, usually to introduce non-linearity.
#
# Examples:
#
# - ReLU
# - Sigmoid
# - Tanh
# - ReLU
#
# Rectified Linear Unit: ReLU(z)=max(0,z)
#
# Meaning:
#
# Negative → 0
#
# Positive → unchanged
#
#
# ##### Sigmoid
#
# Function that converts a real-valued score into a value between 0 and 1:
#
# σ(z)=1/
# 1+e
# −z
# 	​
#
# For binary classification, this lets us interpret a logit as a probability.
#
# ##### Logit
#
# The final layer produces a raw score called a logit.
#
# The neural network's raw output before applying Sigmoid.
#
# ``` text
#
# Logit
# ↓
# Sigmoid
# ↓
# Probability
#
# ```
# p=σ(z)
#
# A logit is not restricted to 0–1.
#
#
# ##### Probability
#
# A value between:
#
# 0≤P≤1
#
# representing the model's estimated likelihood of the positive class.
#
# Example:
#
# 0.82
# → 82% estimated churn probability
#
#
# ##### Classification Threshold
#
# A cutoff used to convert a probability into a predicted class.
#
# Example with threshold 0.5:
#
# Probability < 0.5
# → Class 0
# → No Churn
#
# Probability >= 0.5
# → Class 1
# → Churn
#
# The threshold itself can later be adjusted based on model objectives.
#
# ##### Forward Propagation
#
# The process of moving input data through the neural network to calculate an output(prediction).
#
# Input
# ↓
# Hidden Layers
# ↓
# Output
#
# ##### Backpropagation
#
# The process used to calculate how the loss changes with respect to the network's trainable parameters.
#
# It works backward through the computational graph to calculate gradients.
#
# ##### Gradient
#
# Information describing how sensitive the loss is to a small change in a parameter.
#
# Gradients guide the optimizer when updating weights and biases.
#
# requires_grad=True
#
# Tells PyTorch to track operations involving a tensor/parameter so its gradient can be calculated during backpropagation.
#
# ##### Autograd
#
# PyTorch's automatic differentiation system.
#
# It tracks tensor operations and calculates gradients when:
#
# loss.backward()
#
# is called.
#
# ##### Loss Function
#
# A numerical measure of how far the model's predictions are from the actual targets according to the chosen loss function.
#
# Prediction
# +
# Actual target
# ↓
# Loss function
# ↓
# Loss
#
# Lower loss generally indicates better fit to the training objective.
#
#
# ##### Optimizer
#
# An algorithm that uses gradients to update model parameters.
#
# Examples:
#
# - Gradient Descent
# - SGD
# - Adam
#
# ##### Learning Rate
#
# A hyperparameter controlling the size of parameter updates made by the optimizer.
#
# Conceptually:
#
# new weight=old weight−learning rate×gradient
#
#
# ##### Batch
#
# A subset of training examples processed together.
#
# Example : batch_size = 32
#
# means up to 32 customers are processed together per training step.
#
# ##### Epoch
#
# One complete pass through the training dataset.
#
# For example:
#
# 4,930 training customers
# batch_size = 32
# ≈ 155 batches
#
# All ~155 batches processed = 1 epoch
#
#
# ##### Tensor
#
# PyTorch's primary multidimensional numerical data structure.
#
# Examples:
#
# Scalar       []
# Vector       [45]
# Matrix       [32,45]
#
# ##### TensorDataset
#
# PyTorch utility that pairs input tensors with target tensors.
#
# Conceptually:
#
# Customer features
# ↔
# Customer target
#
#
# ##### DataLoader
#
# PyTorch utility that reads a dataset in batches and can shuffle training examples.
#
# ``` text
#
# TensorDataset
#       ↓
# DataLoader
#       ↓
# Batch 1
# Batch 2
# ...
#
# ```
# .numel() Means: Number of elements.
#
# Example:
#
# Tensor shape
# [32,45]
#
# numel() = 32 × 45=1440
#
# ##### torch.no_grad()
#
# Temporarily disables gradient tracking.
#
# Useful during inference/evaluation when backpropagation is not required.
#
#
# ##### Adam Optimizer
#
# Adam is an adaptive optimization algorithm.
#
# Rather than treating every update identically, Adam keeps running statistics of gradients and uses them to adapt parameter updates.
#
# Conceptually:
#
# ``` text
#
# Current Gradient
#         +
# History of Gradients
#         ↓
# Adam
#         ↓
# Adaptive parameter update
#
# ```
#
# Adam is widely used in Deep Learning.
#
# ###### Batch
#
# Instead of processing the entire training dataset in one operation, training usually processes small groups of observations.
#
# X_batch shape
#
# [32, 45]
#  │   │
#  │   └── features
#  │
#  └────── customers
#
#
# ##### Epoch
#
# One epoch means the model has processed the entire training dataset once.
#
# Training for 20 configured epochs means:
#
# Allow the model up to 20 complete passes through the training data.
#
# Early stopping may terminate training sooner.
#
#
# ##### Training vs Validation
#
# Training data is used to update parameters.
#
# ``` text
#
# Training
#    ↓
# Forward
#    ↓
# Loss
#    ↓
# Backward
#    ↓
# Optimizer
#    ↓
# Weights change
#
# ```
# Validation data evaluates generalization during training:
#
# ``` text
#
# Validation
#    ↓
# Forward only
#    ↓
# Validation loss
#    ↓
# No backpropagation
#    ↓
# No weight updates
#
# ```
#
# This distinction is fundamental.
#
#
# ##### model.train() vs model.eval()
#
# model.train() --> puts the model into training mode.
#
# model.eval() ---> puts the model into evaluation mode.
#
# This becomes especially important with layers whose behavior differs during training and inference, such as Dropout and Batch Normalization.
#
#
# ##### torch.no_grad()
#
# During validation/testing: with torch.no_grad():
#
# tells PyTorch that gradients are unnecessary.
#
# ``` text
#
# No backpropagation needed
#         ↓
# No gradient tracking
#         ↓
# Less memory/computation
#
# ```
#
# ##### Early Stopping
#
# Validation loss helps detect when additional training is no longer improving generalization.
#
# Example:
#
# ``` text
#
# Epoch       Train Loss     Validation Loss
#
# 1              ↓                ↓
# 2              ↓                ↓
# 3              ↓                ↓
# 4              ↓                ↑
# 5              ↓                ↑
#
# ```
#
# The model may be learning the training data increasingly well while validation performance stops improving.
#
# Early stopping says:
#
# Stop training after validation performance fails to improve for a specified patience period.
#
#
# ##### Best Model Checkpoint
#
# The final epoch is not necessarily the best model.
#
# Therefore we save the model state when validation loss improves:
#
# ``` text
#
# Epoch 5
# Validation Loss = BEST
#        ↓
# Save state_dict
#        ↓
#
# Epoch 6
# worse
#
# Epoch 7
# worse
#
# Epoch 8
# worse
#        ↓
# Early stopping
#        ↓
# Restore Epoch 5
#
# ```
# This is why:
#
# model.load_state_dict(
#     best_model_state
# )
#
# was important.
#
#
# ##### state_dict
#
# PyTorch's state_dict() contains the model's learned parameter state.
#
# For our network:
#
# ``` text
#
# layer1.weight
# layer1.bias
#
# layer2.weight
# layer2.bias
#
# output_layer.weight
# output_layer.bias
#
# ```
#
# This is why we could verify:
#
# ``` text
#
# MLflow selected model
#         ↓
# state_dict
#
# Unity Catalog Candidate
#         ↓
# state_dict
#
# Compare
#         ↓
# parameters_verified = True
#
# ```
#
# ##### Parameters vs Hyperparameters
#
# Parameters - Learned automatically:
#
# - Weights
# - Biases
#
# Hyperparameters - Chosen/configured before or around training:
#
# - Learning rate
# - Batch size
# - Number of epochs
# - Hidden layers
# - Number of neurons
# - Optimizer
# - Patience
# - Min delta
#
# Training learns parameters.
#
# Experiments help us choose hyperparameters.
#
#
# ##### Train / Validation / Test
#
# Keep their responsibilities separate:
#
# ``` text
#
# Training Set
#     ↓
# Learn weights and biases
#
#
# Validation Set
#     ↓
# Model selection
# Early stopping
# Hyperparameter comparison
#
#
# Test Set
#     ↓
# Final unbiased evaluation
#
# ```
# A useful rule:
#
# Don't repeatedly make modeling decisions based on the test set, or it effectively becomes another validation set.
#
#
# ##### Precision, Recall and F1
#
# For churn:
#
# ###### Precision
#
# Of customers predicted Churn, how many actually churned?
#
# $$ Precision=\frac{TP}{TP+FP} $$
#
# ###### Recall
#
# Of all actual churners, how many did we detect?
#
# $$ Recall=\frac{TP}{TP+FN} $$
#
# ###### F1
#
# Balances precision and recall:
#
# $$ F1=2\frac{Precision\times Recall}{Precision+Recall} $$
#
# The “best” metric depends on the business cost of false positives versus false negatives.
#
#
# ##### ROC-AUC
#
# ROC-AUC measures the model's ability to rank positive examples above negative examples across thresholds.
#
# Your earlier interpretation was useful: AUC ≈ 0.84
#
# means that if we randomly choose one churner and one non-churner, the model has roughly an 84% chance of assigning the churner a higher risk score.
#
# It does not mean 84% of customers are classified correctly.
#
#
# ###### Deep Learning Training Loop — Big Picture
#
# This is probably the single diagram I would keep in AI_Foundations:
#
# ``` text
#
# Initialize Neural Network
#           ↓
#      Training Batch
#           ↓
#  Forward Propagation
#           ↓
#         Logits
#           ↓
#     Calculate Loss
#           ↓
#    Backpropagation
#           ↓
#       Gradients
#           ↓
#        Adam
#           ↓
# Update Weights + Biases
#           ↓
#      Next Batch
#           ↓
#  ─────────────────────
#    Complete Epoch
#  ─────────────────────
#           ↓
#    Validation Data
#           ↓
#       Forward Only
#           ↓
#    Validation Loss
#           ↓
# Did Validation Improve?
#       /           \
#     YES            NO
#      ↓              ↓
# Save Best       Increase
# Model State     Patience Count
#       \            /
#        \          /
#         Next Epoch
#              ↓
#        Early Stopping
#              ↓
#      Restore Best State
#              ↓
#          Test Set
#
# ```
#
# ##### How This Connects to LLMs
#
# This is one of the most important reasons your NN foundation matters.
#
# A modern LLM is vastly more complex, but many fundamentals remain:
#
# Our Small Neural Network          Large Language Model
#
# Tensor inputs                     Token tensors
#       ↓                                ↓
# Neural-network layers             Transformer layers
#       ↓                                ↓
# Weights                           Billions of weights
#       ↓                                ↓
# Forward propagation               Forward propagation
#       ↓                                ↓
# Logits                            Token logits
#       ↓                                ↓
# Loss                              Language-model loss
#       ↓                                ↓
# Backpropagation                   Backpropagation
#       ↓                                ↓
# Gradients                         Gradients
#       ↓                                ↓
# Optimizer                         Optimizer
#       ↓                                ↓
# Updated weights                   Updated weights
#
#
# ##### Final Mental Model
#
#
# Machine Learning asks:
#
# Can a system learn patterns from data?
#
#
# Neural Networks ask:
#
# Can we learn those patterns through connected layers of trainable parameters?
#
#
# Forward Propagation asks:
#
# What does the current network predict?
#
#
# Loss asks:
#
# How wrong is that prediction?
#
#
# Backpropagation asks:
#
# Which parameters contributed to that error, and in what direction should they change?
#
#
# Gradient asks:
#
# How sensitive is the loss to this parameter?
#
#
# Optimizer asks:
#
# How should we update the parameters?
#
#
# Learning Rate asks:
#
# How large should each update be?
#
#
# Validation asks:
#
# Is the model learning patterns that generalize beyond its training data?
#
#
# Early Stopping asks:
#
# When should we stop learning?
#
#
# Test Evaluation asks:
#
# How well does the final model  on unseen data?
#
#
# MLflow asks:
#
# What did we train, with which configuration,and what happened?
#
#
# Model Registry asks:
#
# Which trained model versions are governed and available?
#
#
# Candidate asks:
#
# Which model are we currently validating?
#
#
# Champion asks:
#
# Which model has been approved?

# %% [markdown]
# ### Timeline

# %% [markdown]
# ###### AI Timeline
# ```text
#
# 1950s
# Rule Based Systems
#         ↓
# 1980s
# Machine Learning
#         ↓
# 2000s
# Deep Learning
#         ↓
# 2013
# Word Embeddings
#         ↓
# 2017
# Transformers
#         ↓
# 2020
# Large Language Models
#         ↓
# 2022
# RAG
#         ↓
# 2024+
# Agentic AI
#
# ```

# %% [markdown]
# ### Common Mistakes & Lessons Learned

# %% [markdown]
# Mistake
#
# Thought model.pkl was the model registry.
#
# Lesson
#
# model.pkl is the serialized model.
#
# Registry manages versions.

# %% [markdown]
# Mistake
#
# Thought TF-IDF was a model.
#
# Lesson
#
# TF-IDF is only feature engineering.

# %% [markdown]
# Mistake
#
# Confused artifact_path with registered model name.
#
# Lesson
#
# artifact_path identifies the logged model inside the MLflow run.

# %% [markdown]
# Mistake
#
# Used Accuracy for multiclass comparison.
#
# Lesson
#
# F1 Macro is a better choice when all classes are equally important.

# %% [markdown]
# Mistake
#
# Forgot input_example while logging.
#
# Lesson
#
# Serving uses it to infer the input schema.

# %% [markdown]
# Mistake:
# Logged a raw sklearn TF-IDF pipeline and deployed it directly to Model Serving.
#
# Lesson:
# The pipeline was trained on a pandas Series, but Model Serving passed a pandas DataFrame based on the model signature. A PyFunc wrapper was needed to extract the text column before calling the pipeline.

# %% [markdown]
# ###### MLflow Text Model Serving
#
# ###### Training
#
# ```text
#
# DataFrame
#       ↓
# Select text column
#       ↓
# Series
#       ↓
# TF-IDF
#       ↓
# Classifier
# ```
#
# ###### Serving
#
# ```text
# REST Request
#       ↓
# DataFrame
#       ↓
# Serving Model
#       ↓
# Prediction
#
# ```
# ###### Lesson
# Always verify that the serving input type matches what the model expects during training.

# %% [markdown]
# Challenging deployment issue.
#
# I deployed a text-classification model to Databricks Model Serving. The model performed correctly during local testing but returned the same class for every prediction through the endpoint. I systematically verified the model, artifacts, payload, endpoint configuration, and signature. I discovered the serving endpoint passed a DataFrame, while my TF-IDF pipeline expected a Pandas Series. I wrapped the pipeline in a custom MLflow PyFunc model that converted the DataFrame into the expected Series before prediction. After re-registering the model and deploying Version 2, the endpoint produced correct predictions.

# %% [markdown]
# The sequence to be followed to debug issue:
#
# - Verified the model locally.
# - Verified the registered model.
# - Verified the endpoint configuration.
# - Verified the model signature.
# - Compared DataFrame vs Series behavior.
# - Identified the input-type mismatch.

# %% [markdown]
# - TF-IDF is feature engineering for text.
# - Embeddings are also feature engineering, but learned automatically.
# - Every AI system converts raw data into a representation before learning.
# - MLflow Experiment is a folder.
#     - MLflow Run is one training execution.
# - A logged model becomes deployable only after it has:
#     - signature
#     - input example
#     - dependencies
# - Unity Catalog stores versions of models, not just model files.
# - Agentic AI extends RAG by allowing an agent to reason and use tools.

# %% [markdown]
# - MLflow artifact_path is not the registered model name.
# - model_uri = run_id + artifact_path.
# - input_example is used to infer the serving schema.
# - signature prevents serving input mismatches.
# - TF-IDF creates features; it does not train the model.
# - Embeddings represent semantic meaning, not word frequency.
