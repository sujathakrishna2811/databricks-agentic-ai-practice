# %%
#verify the file path
volume_path = "/Volumes/dbw_agentic_ai_dev/telco_ai/raw_files"
display(dbutils.fs.ls(volume_path))

# %%
#read_csv file
df = (spark.read.option("header", "true").option("inferSchema", "true").csv("/Volumes/dbw_agentic_ai_dev/telco_ai/raw_files/IBM_Telco_Customer_Churn.csv"))
display(df)

# %%
# verify schema
df.printSchema()

# %%
# create bronze table
df.write.format("delta").mode("overwrite").saveAsTable("dbw_agentic_ai_dev.telco_ai.bronze_telco")

# %%
# %sql
--verify table

SELECT *
FROM dbw_agentic_ai_dev.telco_ai.bronze_telco
LIMIT 10;
