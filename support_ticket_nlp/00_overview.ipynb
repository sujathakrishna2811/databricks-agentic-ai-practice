# %% [markdown]
# ``` text
#
# 01 NLP Foundations
#         ↓
# What is NLP? How can a machine work with text?
#
#
#
# 02 Text Cleaning & Tokenization
#         ↓
# How do we break raw text into usable pieces?
#
#
#
# 03 Vocabulary & Bag of Words
#         ↓
# How do we convert those words into numbers?
#
#
#
# 04 TF-IDF Features
#         ↓
# Are all words equally important?
#
#
#
# 05 Train ML Classifier
#         ↓
# Can Logistic Regression / Naive Bayes / SVM classify tickets?
#
#
#
# 06 Evaluate NLP Classifier
#         ↓
# How well does it distinguish Billing, Technical, Service, etc.?
#
#
#
# 07 Embeddings Foundations
#         ↓
# Can numbers represent the MEANING of text?
#
#
#
# 08 Embedding-Based Classification
#         ↓
# Can semantic representations improve classification?
#
#
#
# 09 Neural Network for Text
#         ↓
# Can our neural network learn patterns from text representations?
#
#
#
# 10 Transformer Foundations
#         ↓
# How can the model understand words IN CONTEXT?
#
#
#
# 11 Transformer Ticket Classifier
#         ↓
# Apply transformer knowledge to the real classification problem
#
#
#
# 12 MLflow Tracking
#         ↓
# Track and compare experiments
#
#
#
# 13 Final Comparison & Conclusion
#         ↓
# BoW vs TF-IDF vs Embeddings vs NN vs Transformer
#
#
# ```

# %% [markdown]
# ``` text
#
# support_ticket_nlp/
# │
# ├── src/
# │   ├── __init__.py
# │   ├── project_config.py
# │   ├── text_preprocessing.py
# │   ├── data_preparation.py
# │   ├── feature_engineering.py
# │   ├── model_training.py
# │   └── model_evaluation.py
# │
# ├── 01_nlp_foundations
# ├── 02_text_cleaning_and_tokenization
# ├── 03_vocabulary_and_bag_of_words
# ├── 04_tfidf_features
# ├── 05_train_ml_classifier
# ├── 06_evaluate_nlp_classifier
# ├── 07_embeddings_foundations
# ├── 08_embedding_based_classification
# ├── 09_neural_network_for_text
# ├── 10_transformer_foundations
# ├── 11_transformer_ticket_classifier
# ├── 12_mlflow_tracking
# ├── 13_model_registration
# ├── 14_model_deployment
# ├── 15_endpoint_testing
# └── 16_final_comparison_and_conclusion
#
# ```
